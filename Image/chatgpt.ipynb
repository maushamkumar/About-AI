# %%
import me
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import me
#
# ModuleNotFoundError: No module named 'me'

# %%
from bytez import Bytez

key = "API KEY"
sdk = Bytez(key)

# choose stable-diffusion-v1-4
model = sdk.model("CompVis/stable-diffusion-v1-4")

# send input to model
output, error = model.run("A cat in a wizard hat")

print({ "error": error, "output": output })
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 10
#       7 model = sdk.model("CompVis/stable-diffusion-v1-4")
#       9 # send input to model
# ---> 10 output, error = model.run("A cat in a wizard hat")
#      12 print({ "error": error, "output": output })
#
# ValueError: too many values to unpack (expected 2)

# %%
OPENAI_API_KEY="API KEY"

# %%
from openai import OpenAI
import base64

# Initialize the client with your API key
client = OpenAI(api_key=OPENAI_API_KEY)

# Generate an image
prompt = "a cyberpunk city skyline at sunset, neon reflections, futuristic vibe"

result = client.images.generate(
    model="gpt-image-1",
    prompt=prompt,
    size="1024x1024"  # options: 256x256, 512x512, 1024x1024
)

# Get the image as base64 and save it
image_base64 = result.data[0].b64_json
image_bytes = base64.b64decode(image_base64)

with open("generated_image.png", "wb") as f:
    f.write(image_bytes)

print("✅ Image saved as 'generated_image.png'")
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[12], line 10
#       7 # Generate an image
#       8 prompt = "a cyberpunk city skyline at sunset, neon reflections, futuristic vibe"
# ---> 10 result = client.images.generate(
#      11     model="gpt-image-1",
#      12     prompt=prompt,
#      13     size="1024x1024"  # options: 256x256, 512x512, 1024x1024
#      14 )
#      16 # Get the image as base64 and save it
#      17 image_base64 = result.data[0].b64_json
#
# File ~/About-AI/venv/lib/python3.9/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# ...

# %%
import requests
r = requests.post(
    "https://api.deepai.org/api/text2img",
    data={
        'text': 'YOUR_TEXT_URL',
    },
    headers={'api-key': 'c2b29f60-da10-4b39-a106-6e7bff4bafb2'}
)
print(r.json())
# Out:
# {'status': 'APIs are only available for Pro members in good standing - please check your Dashboard: https://deepai.org/dashboard'}
